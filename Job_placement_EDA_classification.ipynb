# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %% [markdown]
# # Data

# %%
df = pd.read_csv('datasets/Job_Placement_Data.csv')

# %%
df.head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# ...

# %%
df.columns
# Out:
# Index(['gender', 'ssc_percentage', 'ssc_board', 'hsc_percentage', 'hsc_board',
#        'hsc_subject', 'degree_percentage', 'undergrad_degree',
#        'work_experience', 'emp_test_percentage', 'specialisation',
#        'mba_percent', 'status'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                      count       mean        std    min     25%   50%     75%  \
# ssc_percentage       215.0  67.303395  10.827205  40.89  60.600  67.0  75.700
# hsc_percentage       215.0  66.333163  10.897509  37.00  60.900  65.0  73.000
# degree_percentage    215.0  66.370186   7.358743  50.00  61.000  66.0  72.000
# emp_test_percentage  215.0  72.100558  13.275956  50.00  60.000  71.0  83.500
# mba_percent          215.0  62.278186   5.833385  51.21  57.945  62.0  66.255
#
#                        max
# ssc_percentage       89.40
# hsc_percentage       97.70
# degree_percentage    91.00
# emp_test_percentage  98.00
# mba_percent          77.89

# %%
df.shape
# Out:
# (215, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               215 non-null    object
#  1   ssc_percentage       215 non-null    float64
#  2   ssc_board            215 non-null    object
#  3   hsc_percentage       215 non-null    float64
#  4   hsc_board            215 non-null    object
#  5   hsc_subject          215 non-null    object
#  6   degree_percentage    215 non-null    float64
#  7   undergrad_degree     215 non-null    object
#  8   work_experience      215 non-null    object
#  9   emp_test_percentage  215 non-null    float64
#  10  specialisation       215 non-null    object
#  11  mba_percent          215 non-null    float64
#  12  status               215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
 df.describe(exclude=np.number).T
# Out:
#                  count unique        top freq
# gender             215      2          M  139
# ssc_board          215      2    Central  116
# hsc_board          215      2     Others  131
# hsc_subject        215      3   Commerce  113
# undergrad_degree   215      3  Comm&Mgmt  145
# work_experience    215      2         No  141
# specialisation     215      2    Mkt&Fin  120
# status             215      2     Placed  148

# %%
df.isnull().mean()*100
# Out:
# gender                 0.0
# ssc_percentage         0.0
# ssc_board              0.0
# hsc_percentage         0.0
# hsc_board              0.0
# hsc_subject            0.0
# degree_percentage      0.0
# undergrad_degree       0.0
# work_experience        0.0
# emp_test_percentage    0.0
# specialisation         0.0
# mba_percent            0.0
# status                 0.0
# dtype: float64

# %% [markdown]
# ##### There are 0 null values here

# %%
df.columns
# Out:
# Index(['gender', 'ssc_percentage', 'ssc_board', 'hsc_percentage', 'hsc_board',
#        'hsc_subject', 'degree_percentage', 'undergrad_degree',
#        'work_experience', 'emp_test_percentage', 'specialisation',
#        'mba_percent', 'status'],
#       dtype='object')

# %%
# Showing object columns
df.select_dtypes('O').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            215 non-null    object
#  1   ssc_board         215 non-null    object
#  2   hsc_board         215 non-null    object
#  3   hsc_subject       215 non-null    object
#  4   undergrad_degree  215 non-null    object
#  5   work_experience   215 non-null    object
#  6   specialisation    215 non-null    object
#  7   status            215 non-null    object
# dtypes: object(8)
# memory usage: 13.6+ KB

# %%
# Showing float columns
df.select_dtypes('float64').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ssc_percentage       215 non-null    float64
#  1   hsc_percentage       215 non-null    float64
#  2   degree_percentage    215 non-null    float64
#  3   emp_test_percentage  215 non-null    float64
#  4   mba_percent          215 non-null    float64
# dtypes: float64(5)
# memory usage: 8.5 KB

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# ...

# %%
# calculate the mean and median of different statistics in the dataset
df.groupby('status').agg(['mean', 'median'])
# Out:
#            ssc_percentage        hsc_percentage        degree_percentage  \
#                      mean median           mean median              mean
# status
# Not Placed      57.544030  56.28      58.395522  60.33         61.134179
# Placed          71.721486  72.50      69.926554  68.00         68.740541
#
#                   emp_test_percentage        mba_percent
#            median                mean median        mean  median
# status
# Not Placed   61.0           69.587910   67.0   61.612836  60.690
# Placed       68.0           73.238041   72.0   62.579392  62.245

# %%
# Standard deviation
df.groupby('status').std()
# Out:
#             ssc_percentage  hsc_percentage  degree_percentage  \
# status
# Not Placed        8.394246        9.914090           6.365825
# Placed            8.715445        9.329268           6.518087
#
#             emp_test_percentage  mba_percent
# status
# Not Placed            11.930687     5.705689
# Placed                13.729333     5.884583

# %% [markdown]
# ## Box Plot

# %%
sns.set(style='ticks')
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.boxplot(x='status', y='ssc_percentage', data=df)
plt.subplot(2,3,2)
sns.boxplot(x='status', y='hsc_percentage', data=df)
plt.subplot(2,3,3)
sns.boxplot(x='status', y='degree_percentage', data=df)
plt.subplot(2,3,4)
sns.boxplot(x='status', y='emp_test_percentage', data=df)
plt.subplot(2,3,5)
sns.boxplot(x='status', y='mba_percent', data=df)
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
sns.set(style='ticks')
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.violinplot(x='status', y='ssc_percentage', data=df)
plt.subplot(2,3,2)
sns.violinplot(x='status', y='hsc_percentage', data=df)
plt.subplot(2,3,3)
sns.violinplot(x='status', y='degree_percentage', data=df)
plt.subplot(2,3,4)
sns.violinplot(x='status', y='emp_test_percentage', data=df)
plt.subplot(2,3,5)
sns.violinplot(x='status', y='mba_percent', data=df)
plt.show()

# %%
df.describe()
# Out:
#        ssc_percentage  hsc_percentage  degree_percentage  emp_test_percentage  \
# count      215.000000      215.000000         215.000000           215.000000
# mean        67.303395       66.333163          66.370186            72.100558
# std         10.827205       10.897509           7.358743            13.275956
# min         40.890000       37.000000          50.000000            50.000000
# 25%         60.600000       60.900000          61.000000            60.000000
# 50%         67.000000       65.000000          66.000000            71.000000
# 75%         75.700000       73.000000          72.000000            83.500000
# max         89.400000       97.700000          91.000000            98.000000
#
#        mba_percent
# count   215.000000
# mean     62.278186
# std       5.833385
# min      51.210000
# 25%      57.945000
# 50%      62.000000
# 75%      66.255000
# max      77.890000

# %%
sns.pairplot(df, hue="status")

# %%
plt.figure(figsize=(7,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8,7))
plt.title('ssc_percentage and hsc_percentage')
sns.scatterplot(data=df,x='ssc_percentage',y='hsc_percentage',hue='status',s=50)
# Out:
# <AxesSubplot: title={'center': 'ssc_percentage and hsc_percentage'}, xlabel='ssc_percentage', ylabel='hsc_percentage'>

# %%
fig, axes = plt.subplots(2, 3, figsize=(15,9))
axes[0,0].set_title('ssc_percentage')
axes[0,0].hist(df['ssc_percentage'], bins=5)
axes[0,1].set_title('hsc_percentage')
axes[0,1].hist(df['hsc_percentage'], bins=5)
axes[0,2].set_title('degree_percentage')
axes[0,2].hist(df['degree_percentage'], bins=5)
axes[1,0].set_title('emp_test_percentage')
axes[1,0].hist(df['emp_test_percentage'], bins=5)
axes[1,1].set_title('mba_percent')
axes[1,1].hist(df['mba_percent'], bins=5)
# Out:
# (array([34., 72., 67., 32., 10.]),
#  array([51.21 , 56.546, 61.882, 67.218, 72.554, 77.89 ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## Uni-Variate Analysis

# %%
sns.FacetGrid(df, hue='status', height=5).map(sns.distplot,'ssc_percentage').add_legend();

# %%
sns.FacetGrid(df, hue='status', height=5).map(sns.distplot,'hsc_percentage').add_legend();

# %%
sns.FacetGrid(df, hue='status', height=5).map(sns.distplot,'degree_percentage').add_legend();

# %%
sns.FacetGrid(df, hue='status', height=5).map(sns.distplot,'emp_test_percentage').add_legend();

# %%
sns.FacetGrid(df, hue='status', height=5).map(sns.distplot,'mba_percent').add_legend();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               215 non-null    object
#  1   ssc_percentage       215 non-null    float64
#  2   ssc_board            215 non-null    object
#  3   hsc_percentage       215 non-null    float64
#  4   hsc_board            215 non-null    object
#  5   hsc_subject          215 non-null    object
#  6   degree_percentage    215 non-null    float64
#  7   undergrad_degree     215 non-null    object
#  8   work_experience      215 non-null    object
#  9   emp_test_percentage  215 non-null    float64
#  10  specialisation       215 non-null    object
#  11  mba_percent          215 non-null    float64
#  12  status               215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
df.head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# ...

# %%
# gender
# Senior secondary exams percentage (10th Grade)
# Board of education for ssc exams
# Higher secondary exams percentage (12th Grade)
# Board of education for hsc exams
# Subject of study for hsc
# Percentage of marks in undergrad degree
# Undergrad degree majors
# Past work experience
# Aptitude test percentage
# Postgrad degree majors - (MBA specialization)
# Percentage of marks in MBA degree
# (TARGET) Status of placement. Placed / Not Placed

# %%
fig, axes = plt.subplots(2, 4, figsize=(20, 12))
j = [i for i in df.columns if df[i].dtypes == 'object' and i != 'status']
for i, ax in enumerate(axes.flatten()[:len(j)]):
    sns.countplot(x=j[i], hue='status', data=df, ax=ax)
    ax.set_xlabel(j[i], fontsize=12)
    ax.set_ylabel("Count", fontsize=12)
    ax.set_title(f"Count Plot of {j[i]} by Status", fontsize=14)
plt.tight_layout()

# %%
df['ssc_board'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
df['hsc_board'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
df['hsc_subject'].unique()
# Out:
# array(['Commerce', 'Science', 'Arts'], dtype=object)

# %%
df['undergrad_degree'].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
df['work_experience'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['specialisation'].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
# Counts

fig = plt.figure(figsize=(15,14))
gs  = fig.add_gridspec(3,3)
ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[0,2])
ax4 = fig.add_subplot(gs[1,0])
ax5 = fig.add_subplot(gs[1,1])
ax6 = fig.add_subplot(gs[1,2])
ax7 = fig.add_subplot(gs[2,0])
ax8 = fig.add_subplot(gs[2,1])

# gender 
ax1.set_title('gender',fontweight ="bold",fontsize=15)
ax1.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax1,data=df,x='gender',palette = 'Set1')
ax1.set_xlabel("")

# specialisation
ax2.set_title('specialisation',fontweight ="bold",fontsize=15)
ax2.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax2,data=df,x='specialisation',palette = 'Set1')
ax2.set_xlabel("")

# ssc_board 
ax3.set_title('ssc board',fontweight ="bold",fontsize=15)
ax3.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax3,data=df,x='ssc_board',palette = 'Set1')
ax3.set_xlabel("")

#  hsc_board
ax4.set_title('hsc board',fontweight ="bold",fontsize=15)
ax4.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax4,data=df,x='hsc_board',palette = 'Set1')
ax4.set_xlabel("")

# hsc_subject
ax5.set_title('hsc subject',fontweight ="bold",fontsize=15)
ax5.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax5,data=df,x='hsc_subject',palette = 'Set1')
ax5.set_xlabel("")

# undergrad_degree
ax6.set_title('undergrad degree',fontweight ="bold",fontsize=15)
ax6.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax6,data=df,x='undergrad_degree',palette = 'Set1')
ax6.set_xlabel("")

# work_experience
ax7.set_title('work experience',fontweight ="bold",fontsize=15)
ax7.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax7,data=df,x='work_experience',palette = 'Set1')
ax7.set_xlabel("")

# status
ax8.set_title('status',fontweight ="bold",fontsize=15)
ax8.grid(color='#000000', linestyle='dashed', axis='y',dashes=(1,9))
sns.countplot(ax=ax8,data=df,x='status',palette = 'Set1')
ax8.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ## Turning obj to int

# %%
# easy way to turn objects & integers
le = LabelEncoder()
object_columns = [col for col in df.columns if df[col].dtypes == 'object']
df[object_columns] = df[object_columns].apply(le.fit_transform)

# %%
df.head()
# Out:
#    gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  hsc_subject  \
# 0       1           67.00          1           91.00          1            1
# 1       1           79.33          0           78.33          1            2
# 2       1           65.00          0           68.00          0            0
# 3       1           56.00          0           52.00          0            2
# 4       1           85.80          0           73.60          0            1
#
#    degree_percentage  undergrad_degree  work_experience  emp_test_percentage  \
# 0              58.00                 2                0                 55.0
# 1              77.48                 2                1                 86.5
# 2              64.00                 0                0                 75.0
# 3              52.00                 2                0                 66.0
# 4              73.30                 0                0                 96.8
#
#    specialisation  mba_percent  status
# ...

# %%
sns.set(style='ticks')
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.violinplot(x='status', y='ssc_board', data=df)
plt.subplot(2,3,2)
sns.violinplot(x='status', y='hsc_board', data=df)
plt.subplot(2,3,3)
sns.violinplot(x='status', y='undergrad_degree', data=df)
plt.subplot(2,3,4)
sns.violinplot(x='status', y='hsc_subject', data=df)
plt.subplot(2,3,5)
sns.violinplot(x='status', y='work_experience', data=df)
plt.subplot(2,3,6)
sns.violinplot(x='status', y='specialisation', data=df)
plt.show()

# %%
plt.figure(figsize=(9,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.plot()
# Out:
# []

# %% [markdown]
# # Classification

# %% [markdown]
# ### Train and Test

# %%
df.head()
# Out:
#    gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  hsc_subject  \
# 0       1           67.00          1           91.00          1            1
# 1       1           79.33          0           78.33          1            2
# 2       1           65.00          0           68.00          0            0
# 3       1           56.00          0           52.00          0            2
# 4       1           85.80          0           73.60          0            1
#
#    degree_percentage  undergrad_degree  work_experience  emp_test_percentage  \
# 0              58.00                 2                0                 55.0
# 1              77.48                 2                1                 86.5
# 2              64.00                 0                0                 75.0
# 3              52.00                 2                0                 66.0
# 4              73.30                 0                0                 96.8
#
#    specialisation  mba_percent  status
# ...

# %% [markdown]
# ### Preparing x and y

# %% [markdown]
# ### Train test split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=0)

# %% [markdown]
# ## Model

# %% [markdown]
# ### LogisticRegression

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Fit
lr = LogisticRegression()
lr.fit(X_train,y_train)

# prediction
y_pred = lr.predict(X_test)

# %%
lr_score = accuracy_score(y_test,y_pred)
print(f"Score %{(lr_score*100):.2f}")
# Out:
# Score %84.62

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[12  7]
#  [ 3 43]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.63      0.71        19
#            1       0.86      0.93      0.90        46
#
#     accuracy                           0.85        65
#    macro avg       0.83      0.78      0.80        65
# weighted avg       0.84      0.85      0.84        65

# %%
# Sınıflandırma grafiği çizdirin
plt.figure(figsize=(8, 6))
plt.scatter(X_test['ssc_percentage'], X_test['degree_percentage'], c=y_pred)
plt.xlabel('ssc_percentage')
plt.ylabel('degree_percentage')
plt.title('Sınıflandırma grafiği')
plt.show()

# %% [markdown]
# ### KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
test_score = []
train_score = []

for i in range(1, 20):
    knn = KNeighborsClassifier(i)
    knn.fit(X_train, y_train)
    train_score.append(knn.score(X_train, y_train))
    test_score.append(knn.score(X_test, y_test))

# max scores
max_train_score = max(train_score)
train_score_ind = [i for i, v in enumerate(train_score) if v == max_train_score]
 
max_test_score = max(test_score)
test_score_ind = [i for i, v in enumerate(test_score) if v == max_test_score]


print(f'Max Train Score : %{max_train_score * 100} - K : {list(map(lambda x: x+1, train_score_ind))}')
print(f'Max Test Score : %{max_test_score * 100} - Best K : {list(map(lambda x: x+1, test_score_ind))}')

# graph

plt.figure(figsize=(12, 5))
p = sns.lineplot(train_score, marker="*", label="Train Score")
p = sns.lineplot(test_score, marker="o", label="Test Score")
plt.show()
# Out:
# Max Train Score : %100.0 - K : [1]
# Max Test Score : %80.0 - Best K : [7, 9, 10, 11, 13, 14]

# %% [markdown]
# ### GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
# Train the Random Forest classifier
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Predict the target values for the test data
y_pred = gnb.predict(X_test)

# %%
# Evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 81.54%

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[13  6]
#  [ 6 40]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68        19
#            1       0.87      0.87      0.87        46
#
#     accuracy                           0.82        65
#    macro avg       0.78      0.78      0.78        65
# weighted avg       0.82      0.82      0.82        65

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Train the Random Forest classifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

# Predict the target values for the test data
y_pred = rfc.predict(X_test)

# %%
# Evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 76.92%

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[ 9 10]
#  [ 5 41]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.47      0.55        19
#            1       0.80      0.89      0.85        46
#
#     accuracy                           0.77        65
#    macro avg       0.72      0.68      0.70        65
# weighted avg       0.76      0.77      0.76        65

# %% [markdown]
# ## Summary / Özet

# %% [markdown]
# ### TR

# %% [markdown]
# %80 - %90 arası yüzdeler job placement altında yeterli olacaktır diye düşünüyorum, şu anda test verisinin oranı %30 bunu değiştirmek sınıflandırma skoruna etki edecektir. Eğer yüzdeyi artırmak istersek veri setini artırmamız gerekmektedir, çünkü sadece 215 tane veri var bu yeterli değil. Burada sadece dört adet sınıflandırma kullandım belki başka sınıflandırmalar daha doğru oranlar vericektir denemeden bilemeyiz.
#
# En iyi sonucu LogisticRegression verdi, %84.62. Eğer bir program yapılacaksa veya bir iş için kullanılacaksa daha kaliteli bir veri seti daha iyi sonuç vecektir.

# %% [markdown]
# ### ENG

# %% [markdown]
# I think percentages between 80% - 90% will be good for job placement, currently test data has 30% of data. if we change the test data percent it'll change the classification score.  If we want to increase the percentage we need to increase the dataset, because data set is small there are only 215 rows. Here, there are only four classification, maybe others will give more accurate ratios, we cannot know until we try.
#
# LogisticRegression has the best score, 84.62%.
