# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %% [markdown]
# # Data

# %%
df = pd.read_csv('datasets/smoking.csv')

# %%
df.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
df.shape
# Out:
# (55692, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   55692 non-null  int64
#  1   gender               55692 non-null  object
#  2   age                  55692 non-null  int64
#  3   height(cm)           55692 non-null  int64
#  4   weight(kg)           55692 non-null  int64
#  5   waist(cm)            55692 non-null  float64
#  6   eyesight(left)       55692 non-null  float64
#  7   eyesight(right)      55692 non-null  float64
#  8   hearing(left)        55692 non-null  float64
#  9   hearing(right)       55692 non-null  float64
#  10  systolic             55692 non-null  float64
#  11  relaxation           55692 non-null  float64
#  12  fasting blood sugar  55692 non-null  float64
#  13  Cholesterol          55692 non-null  float64
#  14  triglyceride         55692 non-null  float64
# ...

# %% [markdown]
# There is zero null value, thats a good thing.
#
# Hiç null değer yok, bu bizim için iyi bir şey.

# %%
df.describe().T
# Out:
#                        count          mean           std    min       25%  \
# ID                   55692.0  27845.500000  16077.039933    0.0  13922.75
# age                  55692.0     44.182917     12.071418   20.0     40.00
# height(cm)           55692.0    164.649321      9.194597  130.0    160.00
# weight(kg)           55692.0     65.864936     12.820306   30.0     55.00
# waist(cm)            55692.0     82.046418      9.274223   51.0     76.00
# eyesight(left)       55692.0      1.012623      0.486873    0.1      0.80
# eyesight(right)      55692.0      1.007443      0.485964    0.1      0.80
# hearing(left)        55692.0      1.025587      0.157902    1.0      1.00
# hearing(right)       55692.0      1.026144      0.159564    1.0      1.00
# systolic             55692.0    121.494218     13.675989   71.0    112.00
# relaxation           55692.0     76.004830      9.679278   40.0     70.00
# fasting blood sugar  55692.0     99.312325     20.795591   46.0     89.00
# ...

# %% [markdown]
# # EDA

# %%
sns.countplot(data= df, x="smoking")
# Out:
# <AxesSubplot: xlabel='smoking', ylabel='count'>

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
j = [i for i in df.columns if df[i].dtypes == 'object' and i != 'smoking']
for i, ax in enumerate(axes.flatten()[:len(j)]):
    sns.countplot(x=j[i], hue='smoking', data=df, ax=ax)
    ax.set_xlabel(j[i], fontsize=12)
    ax.set_ylabel("Count", fontsize=12)
    ax.set_title(f"Count Plot of {j[i]} by Smoking", fontsize=14)
plt.tight_layout()

# %%
columns = [i for i in df.columns if (df[i].dtypes == 'float64' or df[i].dtypes == 'int64') and (i != 'smoking' and i != 'ID')]

# %% [markdown]
# ## Box Plot

# %%
sns.set(style='ticks')
plt.figure(figsize=(15,30))

for i in range(1,len(columns)):
    plt.subplot(8,3,i)
    sns.boxplot(x='smoking', y=columns[i], data=df)

# %% [markdown]
# ## Violin Plot

# %%
sns.set(style='ticks')
plt.figure(figsize=(15,30))

for i in range(1,len(columns)):
    plt.subplot(8,3,i)
    sns.violinplot(x='smoking', y=columns[i], data=df)

# %% [markdown]
# ## Heatmap

# %%
df = df.drop(['ID'], axis=1)

df_without_output = df.drop(['smoking'], axis=1)
plt.figure(figsize=(25,24))
sns.heatmap(df_without_output.corr(), annot=True, cmap='coolwarm')
plt.plot()
# Out:
# []

# %% [markdown]
# #### Turn objects to integers

# %%
le = LabelEncoder()
object_columns = [col for col in df.columns if df[col].dtypes == 'object']
df[object_columns] = df[object_columns].apply(le.fit_transform)

# %%
df.head()
# Out:
#    gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       0   40         155          60       81.3             1.2
# 1       0   40         160          60       81.0             0.8
# 2       1   55         170          60       80.0             0.8
# 3       1   40         165          70       88.0             1.5
# 4       0   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.6            1.0             1.0     119.0  ...        12.7
# 2              0.8            1.0             1.0     138.0  ...        15.8
# 3              1.5            1.0             1.0     100.0  ...        14.7
# 4              1.0            1.0             1.0     120.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
df_without_output = df.drop(['smoking','oral'], axis=1)
plt.figure(figsize=(25,24))
sns.heatmap(df_without_output.corr(), annot=True, cmap='coolwarm')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8,7))
plt.title('gender and height(cm)')
sns.scatterplot(data=df,x='gender',y='height(cm)',hue='smoking',s=50)
# Out:
# <AxesSubplot: title={'center': 'gender and height(cm)'}, xlabel='gender', ylabel='height(cm)'>

# %%
plt.figure(figsize=(8,7))
plt.title('LDL and Cholesterol')
sns.scatterplot(data=df,x='LDL',y='Cholesterol',hue='smoking',s=50)
# Out:
# <AxesSubplot: title={'center': 'LDL and Cholesterol'}, xlabel='LDL', ylabel='Cholesterol'>

# %%
plt.figure(figsize=(8,7))
plt.title('waist(cm) and weight(kg)')
sns.scatterplot(data=df,x='waist(cm)',y='weight(kg)',hue='smoking',s=50)
# Out:
# <AxesSubplot: title={'center': 'waist(cm) and weight(kg)'}, xlabel='waist(cm)', ylabel='weight(kg)'>

# %%
plt.figure(figsize=(8,7))
plt.title('systolic and relaxation')
sns.scatterplot(data=df,x='systolic',y='relaxation',hue='smoking',s=50)
# Out:
# <AxesSubplot: title={'center': 'systolic and relaxation'}, xlabel='systolic', ylabel='relaxation'>

# %%
plt.figure(figsize=(8,7))
plt.title('AST and ALT')
sns.scatterplot(data=df,x='AST',y='ALT',hue='smoking',s=50)
# Out:
# <AxesSubplot: title={'center': 'AST and ALT'}, xlabel='AST', ylabel='ALT'>

# %%
plt.figure(figsize=(8,7))
plt.title('hemoglobin and gender')
sns.scatterplot(data=df,x='hemoglobin',y='gender',hue='smoking',s=50)
# Out:
# <AxesSubplot: title={'center': 'hemoglobin and gender'}, xlabel='hemoglobin', ylabel='gender'>

# %%
for col in columns:
    sns.FacetGrid(df, hue='smoking', height=5).map(sns.distplot,col).add_legend();

# %% [markdown]
# # Classification

# %% [markdown]
# ## Train and Test

# %% [markdown]
# ### Preparing X and y data

# %%
X = df.drop(['smoking','oral'],axis=1)
y = df.smoking

# %% [markdown]
# #### Nomalization

# %%
X = (X - X.mean()) / X.std()

# %% [markdown]
# ### Train test split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=0)

# %% [markdown]
# # Model

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Fit
lr = LogisticRegression()
lr.fit(X_train,y_train)

# prediction
y_pred = lr.predict(X_test)

# %%
lr_score = accuracy_score(y_test,y_pred)
print(f"Score {(lr_score*100):.2f}%")
# Out:
# Score 74.67%

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[5463 1613]
#  [1209 2854]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79      7076
#            1       0.64      0.70      0.67      4063
#
#     accuracy                           0.75     11139
#    macro avg       0.73      0.74      0.73     11139
# weighted avg       0.75      0.75      0.75     11139

# %% [markdown]
# ### KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
test_train_scores = []

for i in range(1, 10):
    knn = KNeighborsClassifier(i)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    test_train_scores.append((train_score, test_score))

test_train_scores = np.array(test_train_scores)

max_train_score = np.max(test_train_scores[:,0])
train_score_ind = np.where(test_train_scores[:,0] == max_train_score)[0] + 1
max_test_score = np.max(test_train_scores[:,1])
test_score_ind = np.where(test_train_scores[:,1] == max_test_score)[0] + 1

print(f'Max Train Score : {max_train_score * 100:.2f}% - K : {train_score_ind}')
print(f'Max Test Score : {max_test_score * 100:.2f}% - Best K : {test_score_ind}')

sns.set_style('whitegrid')
plt.figure(figsize=(12, 5))
sns.lineplot(data=test_train_scores, markers=True)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Max Train Score : 100.00% - K : [1]
# Max Test Score : 78.86% - Best K : [1]

# %% [markdown]
# ### GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
# Train the Random Forest classifier
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Predict the target values for the test data
y_pred = gnb.predict(X_test)

# %%
gnb_score = accuracy_score(y_test,y_pred)
print(f"Score {(gnb_score*100):.2f}%")
# Out:
# Score 70.47%

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[4517 2559]
#  [ 730 3333]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.64      0.73      7076
#            1       0.57      0.82      0.67      4063
#
#     accuracy                           0.70     11139
#    macro avg       0.71      0.73      0.70     11139
# weighted avg       0.75      0.70      0.71     11139

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Train the Random Forest classifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

# Predict the target values for the test data
y_pred = rfc.predict(X_test)

# %%
rfc_score = accuracy_score(y_test,y_pred)
print(f"Score {(rfc_score*100):.2f}%")
# Out:
# Score 83.71%

# %%
con_mat = confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[6078  998]
#  [ 816 3247]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      7076
#            1       0.76      0.80      0.78      4063
#
#     accuracy                           0.84     11139
#    macro avg       0.82      0.83      0.83     11139
# weighted avg       0.84      0.84      0.84     11139

# %% [markdown]
# # Özet / Summary

# %% [markdown]
# Test yüzdesi %20 olarak ayarladığımız zaman RandomForestClassifier sınıflandırması ile %84 gibi iyi bir sonuç elde ettik, bu sonucu artırmak için verisetinin kapasitesini artırabiliriz veya verisetini düzenliyebiliriz ama pek fazla bilgi sahibi olmadığım için ve veri seti gözüme düzgün geldiği için düzeltme yapmadım.
#
# When we set the test percentage to 20%, we got a good result of 84% with RandomForestClassifier classification, we can increase the capacity of the dataset to increase this result or we can edit the dataset, but I didn't edit because I don't have much knowledge and the dataset looks good to me.
